# %% [markdown]
# <br>

# %%
import numpy as np
import pandas as pd

import folium

# %% [markdown]
# <br>

# %% [markdown]
# ## Visualize CO2 emissions per capita using Folium

# %%
path = "D:/KeepStudy/01_Edx/3 Data Science MicroMasters Program (UCSanDiegoX)/3.1 Python for Data Science (DSE200x)/Notebooks/W5 Data Visualization/"

country_geo = path + 'geo/world-countries.json'

df_co2 = pd.read_csv(path + r"world-development-indicators/Indicators.csv")
df_co2
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# ...             ...         ...
# 5656453    Zimbabwe         ZWE
# 5656454    Zimbabwe         ZWE
# 5656455    Zimbabwe         ZWE
# 5656456    Zimbabwe         ZWE
# 5656457    Zimbabwe         ZWE
#
#                                              IndicatorName      IndicatorCode  \
# 0        Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1        Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2        Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3        Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4              Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# ...                                                    ...                ...
# 5656453          Time required to register property (days)        IC.PRP.DURS
# 5656454           Time required to start a business (days)        IC.REG.DURS
# 5656455              Time to prepare and pay taxes (hours)        IC.TAX.DURS
# 5656456                 Time to resolve insolvency (years)        IC.ISV.DURS
# 5656457           Total tax rate (% of commercial profits)  IC.TAX.TOTL.CP.ZS
#
#          Year         Value
# 0        1960  1.335609e+02
# 1        1960  8.779760e+01
# 2        1960  6.634579e+00
# 3        1960  8.102333e+01
# 4        1960  3.000000e+06
# ...       ...           ...
# 5656453  2015  3.600000e+01
# 5656454  2015  9.000000e+01
# 5656455  2015  2.420000e+02
# 5656456  2015  3.300000e+00
# 5656457  2015  3.280000e+01
#
# [5656458 rows x 6 columns]

# %% [markdown]
# <br>

# %%
# select CO2 emissions for all countries in 2011
hist_indicator = 'CO2 emissions \(metric'
hist_year = 2011

mask1 = df_co2['IndicatorName'].str.contains(hist_indicator) 
mask2 = df_co2['Year'].isin([hist_year])

# apply our mask
df_mask = df_co2[mask1 & mask2]
df_mask
# Out:
#                                      CountryName CountryCode  \
# 5026275                               Arab World         ARB
# 5026788                   Caribbean small states         CSS
# 5027295           Central Europe and the Baltics         CEB
# 5027870  East Asia & Pacific (all income levels)         EAS
# 5028456    East Asia & Pacific (developing only)         EAP
# ...                                          ...         ...
# 5198435                                  Vietnam         VNM
# 5199322                       West Bank and Gaza         WBG
# 5199936                              Yemen, Rep.         YEM
# 5200687                                   Zambia         ZMB
# 5201543                                 Zimbabwe         ZWE
#
#                                   IndicatorName   IndicatorCode  Year  \
# 5026275  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5026788  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5027295  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5027870  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5028456  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# ...                                         ...             ...   ...
# 5198435  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5199322  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5199936  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5200687  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
# 5201543  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2011
#
#             Value
# 5026275  4.724500
# 5026788  9.692960
# 5027295  6.911131
# 5027870  5.859548
# 5028456  5.302499
# ...           ...
# 5198435  1.971889
# 5199322  0.572407
# 5199936  0.919968
# 5200687  0.212450
# 5201543  0.691698
#
# [232 rows x 6 columns]

# %% [markdown]
# <br>

# %%
plot_data = df_mask[['CountryCode','Value']]
plot_data
# Out:
#         CountryCode     Value
# 5026275         ARB  4.724500
# 5026788         CSS  9.692960
# 5027295         CEB  6.911131
# 5027870         EAS  5.859548
# 5028456         EAP  5.302499
# ...             ...       ...
# 5198435         VNM  1.971889
# 5199322         WBG  0.572407
# 5199936         YEM  0.919968
# 5200687         ZMB  0.212450
# 5201543         ZWE  0.691698
#
# [232 rows x 2 columns]

# %% [markdown]
# <br>

# %%
# label for the legend
hist_indicator = df_mask.iloc[0]['IndicatorName']
hist_indicator
# Out:
# 'CO2 emissions (metric tons per capita)'

# %%
# Setup a folium map at a high-level zoom @Alok 
# - what is the 100,0, doesn't seem like lat long
map = folium.Map(location=[100, 0], zoom_start=1.5)

# %%
# choropleth maps bind Pandas Data Frames and json geometries.  
# This allows us to quickly visualize data combinations
map.choropleth(geo_data=country_geo, 
               data=plot_data,
               columns=['CountryCode', 'Value'],
               key_on='feature.id',
               fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2,
               legend_name=hist_indicator)
# Out:
# D:\Programs\Anaconda3\envs\tfg\lib\site-packages\folium\folium.py:409: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   warnings.warn(

# %%
# Create Folium plot
map.save('./plot_data/CO2_emissions_per_capita.html')

# %%
# Import the Folium interactive html file
from IPython.display import HTML
HTML('<iframe src=./plot_data/CO2_emissions_per_capita.html width=700 height=450></iframe>')
# Out:
# D:\Programs\Anaconda3\envs\tfg\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=./plot_data/CO2_emissions_per_capita.html width=700 height=450></iframe>

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## 示例

# %% [markdown]
# 下面这几段代码参考自：https://www.delftstack.com/howto/python/folium-package-in-python/

# %% [markdown]
# ### Add a circle marker

# %% [markdown]
# We will use the **circleMarker()** method to add a circular marker on the map and pass the location, radius, and popup text as arguments.

# %%
my_map = folium.Map(location = [24.860966, 66.990501], zoom_start = 12)


folium.CircleMarker(location = [24.860966, 66.990501], 
                    radius = 40, popup = 'My Location').add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19e17c4676a12af9de131bf9df61a906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19e17c4676a12af9de131bf9df61a906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19e17c4676a12af9de131bf9df61a906 = L.map(
#                 &quot;map_19e17c4676a12af9de131bf9df61a906&quot;,
#                 {
#                     center: [24.860966, 66.990501],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28b97c0fe82e81619e5a51c9837b5a04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#             var circle_marker_7ef98e284528670ce863b471e8ebf85d = L.circleMarker(
#                 [24.860966, 66.990501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_4a2b430bc7ce5e0dbb297919b90dd00a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b38a0f6c67b5d81dce7dcc44b5f8eb2a = $(`&lt;div id=&quot;html_b38a0f6c67b5d81dce7dcc44b5f8eb2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Location&lt;/div&gt;`)[0];
#             popup_4a2b430bc7ce5e0dbb297919b90dd00a.setContent(html_b38a0f6c67b5d81dce7dcc44b5f8eb2a);
#
#
#         circle_marker_7ef98e284528670ce863b471e8ebf85d.bindPopup(popup_4a2b430bc7ce5e0dbb297919b90dd00a)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>

# %% [markdown]
# ### Add a parachute marker

# %% [markdown]
# A **parachute marker** is the standard way to represent a location on the map. We will use the Marker() method to add a parachute marker and pass the location and popup text arguments.

# %%
folium.Marker([24.860966, 66.990501], popup = 'My Place').add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19e17c4676a12af9de131bf9df61a906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19e17c4676a12af9de131bf9df61a906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19e17c4676a12af9de131bf9df61a906 = L.map(
#                 &quot;map_19e17c4676a12af9de131bf9df61a906&quot;,
#                 {
#                     center: [24.860966, 66.990501],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28b97c0fe82e81619e5a51c9837b5a04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#             var circle_marker_7ef98e284528670ce863b471e8ebf85d = L.circleMarker(
#                 [24.860966, 66.990501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_4a2b430bc7ce5e0dbb297919b90dd00a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b38a0f6c67b5d81dce7dcc44b5f8eb2a = $(`&lt;div id=&quot;html_b38a0f6c67b5d81dce7dcc44b5f8eb2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Location&lt;/div&gt;`)[0];
#             popup_4a2b430bc7ce5e0dbb297919b90dd00a.setContent(html_b38a0f6c67b5d81dce7dcc44b5f8eb2a);
#
#
#         circle_marker_7ef98e284528670ce863b471e8ebf85d.bindPopup(popup_4a2b430bc7ce5e0dbb297919b90dd00a)
#         ;
#
#
#
#
#             var circle_marker_244239fe94818235f7131723143ee3d6 = L.circleMarker(
#                 [24.860966, 66.990501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_af0af20c49da7782683072c82f8b554a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9da95f5743ef39909ef6ac7c8e7bc26 = $(`&lt;div id=&quot;html_c9da95f5743ef39909ef6ac7c8e7bc26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Location&lt;/div&gt;`)[0];
#             popup_af0af20c49da7782683072c82f8b554a.setContent(html_c9da95f5743ef39909ef6ac7c8e7bc26);
#
#
#         circle_marker_244239fe94818235f7131723143ee3d6.bindPopup(popup_af0af20c49da7782683072c82f8b554a)
#         ;
#
#
#
#
#             var marker_32ae753112dab4567620131342c6e459 = L.marker(
#                 [24.860966, 66.990501],
#                 {}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_55bd2f9e9ef37b3204f9185f005c47db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b645f0ebfb139ceb02e64752418490f2 = $(`&lt;div id=&quot;html_b645f0ebfb139ceb02e64752418490f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Place&lt;/div&gt;`)[0];
#             popup_55bd2f9e9ef37b3204f9185f005c47db.setContent(html_b645f0ebfb139ceb02e64752418490f2);
#
#
#         marker_32ae753112dab4567620131342c6e459.bindPopup(popup_55bd2f9e9ef37b3204f9185f005c47db)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <br>

# %% [markdown]
# ### Add a Line Between Two Locations on a Map

# %% [markdown]
# We will see both the locations on a map and a line that connects them in the output. This is helpful when we want to see how far apart the two places are from each other.

# %%
folium.Marker([24.7077, 66.0501], popup = 'Location 2').add_to(my_map)
folium.PolyLine(locations = [(24.860966, 66.990501), (24.7077, 66.0501)], line_opacity = 0.5).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19e17c4676a12af9de131bf9df61a906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19e17c4676a12af9de131bf9df61a906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_19e17c4676a12af9de131bf9df61a906 = L.map(
#                 &quot;map_19e17c4676a12af9de131bf9df61a906&quot;,
#                 {
#                     center: [24.860966, 66.990501],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28b97c0fe82e81619e5a51c9837b5a04 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#             var circle_marker_7ef98e284528670ce863b471e8ebf85d = L.circleMarker(
#                 [24.860966, 66.990501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_4a2b430bc7ce5e0dbb297919b90dd00a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b38a0f6c67b5d81dce7dcc44b5f8eb2a = $(`&lt;div id=&quot;html_b38a0f6c67b5d81dce7dcc44b5f8eb2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Location&lt;/div&gt;`)[0];
#             popup_4a2b430bc7ce5e0dbb297919b90dd00a.setContent(html_b38a0f6c67b5d81dce7dcc44b5f8eb2a);
#
#
#         circle_marker_7ef98e284528670ce863b471e8ebf85d.bindPopup(popup_4a2b430bc7ce5e0dbb297919b90dd00a)
#         ;
#
#
#
#
#             var circle_marker_244239fe94818235f7131723143ee3d6 = L.circleMarker(
#                 [24.860966, 66.990501],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 40, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_af0af20c49da7782683072c82f8b554a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c9da95f5743ef39909ef6ac7c8e7bc26 = $(`&lt;div id=&quot;html_c9da95f5743ef39909ef6ac7c8e7bc26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Location&lt;/div&gt;`)[0];
#             popup_af0af20c49da7782683072c82f8b554a.setContent(html_c9da95f5743ef39909ef6ac7c8e7bc26);
#
#
#         circle_marker_244239fe94818235f7131723143ee3d6.bindPopup(popup_af0af20c49da7782683072c82f8b554a)
#         ;
#
#
#
#
#             var marker_32ae753112dab4567620131342c6e459 = L.marker(
#                 [24.860966, 66.990501],
#                 {}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_55bd2f9e9ef37b3204f9185f005c47db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b645f0ebfb139ceb02e64752418490f2 = $(`&lt;div id=&quot;html_b645f0ebfb139ceb02e64752418490f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;My Place&lt;/div&gt;`)[0];
#             popup_55bd2f9e9ef37b3204f9185f005c47db.setContent(html_b645f0ebfb139ceb02e64752418490f2);
#
#
#         marker_32ae753112dab4567620131342c6e459.bindPopup(popup_55bd2f9e9ef37b3204f9185f005c47db)
#         ;
#
#
#
#
#             var marker_c913dbbf6a0d82cd949828df409e61af = L.marker(
#                 [24.7077, 66.0501],
#                 {}
#             ).addTo(map_19e17c4676a12af9de131bf9df61a906);
#
#
#         var popup_6d791ab2a2d1a9cec6b0b469fa1c8bcf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_32e527921bbc6d57cde85d3f774ea616 = $(`&lt;div id=&quot;html_32e527921bbc6d57cde85d3f774ea616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Location 2&lt;/div&gt;`)[0];
#             popup_6d791ab2a2d1a9cec6b0b469fa1c8bcf.setContent(html_32e527921bbc6d57cde85d3f774ea616);
#
#
#         marker_c913dbbf6a0d82cd949828df409e61af.bindPopup(popup_6d791ab2a2d1a9cec6b0b469fa1c8bcf)
#         ;
#
#
#
#
#             var poly_line_d30d7e70d18d1f6a5f9d3b1c2680c307 = L.polyline(
#                 [[24.860966, 66.990501], [24.7077, 66.0501]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quo

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ## 在地图上显示前200条犯罪数据

# %% [markdown]
# 链接：
# * 【Python 实用宝典】 https://pythondict.com/python-paintings/folium/

# %% [markdown]
# ### 显示犯罪地点

# %%
san_map = folium.Map(location=[37.77, -122.42], zoom_start=12,width='66%',height='66%')

# %%
# cdata = pd.read_csv('https://cocl.us/sanfran_crime_dataset')
data_path = './datasets/Police_Department_Incidents_-_Previous_Year__2016_.csv'

df_crime = pd.read_csv(data_path) # 犯罪数据，包含犯罪所在经纬度
df_crime.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
# 2   KEITH ST / SHAFTER AV -122.388856  37.729981
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000

# %%
# get the first 200 crimes in the cdata
limit = 200
data = df_crime.iloc[0:limit, :]

# Instantiate a feature group for the incidents in the dataframe
incidents_featureGroup = folium.map.FeatureGroup()

# Loop through the 200 crimes and add each to the incidents feature group
for lat, lng, in zip(df_crime.Y, data.X):
    incidents_featureGroup.add_child(folium.CircleMarker([lat, lng],
                                            radius=7,   # define how big you want the circle markers to be
                                            color='yellow',
                                            fill=True,
                                            fill_color='red',
                                            fill_opacity=0.4
                                           )
                       )


san_map.add_child(incidents_featureGroup)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71590cd787592cc916dddb5785e13f11 {
#                     position: relative;
#                     width: 66.0%;
#                     height: 66.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71590cd787592cc916dddb5785e13f11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_71590cd787592cc916dddb5785e13f11 = L.map(
#                 &quot;map_71590cd787592cc916dddb5785e13f11&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1614fd4f78dc26b40a4126ba2357269a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71590cd787592cc916dddb5785e13f11);
#
#
#             var feature_group_d25f582d25908c4c04a43196e03b940f = L.featureGroup(
#                 {}
#             ).addTo(map_71590cd787592cc916dddb5785e13f11);
#
#
#             var circle_marker_c25c60cb76bdd771f48e5f0f2512a9e1 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_e9c6a8f33cbbee221cbaf771bae4627c = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_53acb712c910c9fbfba9536b6e898180 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_39b8f9002576237e96ba4cc59adda36c = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_99e000af8ca094af06910b215156baf6 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_df1ff4024725a7c7ee07aa397a56af57 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# ### 统计区域犯罪总数

# %%
from folium import plugins

# %%
# instantiate a mark cluster object for the incidents in the dataframe
incidents_markCluster = plugins.MarkerCluster().add_to(san_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(data.Y, data.X, df_crime.Category):
    folium.Marker(location=[lat, lng],
                  icon=None,
                  popup=label,
                 ).add_to(incidents_markCluster)

# add incidents to map
san_map.add_child(incidents_markCluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71590cd787592cc916dddb5785e13f11 {
#                     position: relative;
#                     width: 66.0%;
#                     height: 66.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71590cd787592cc916dddb5785e13f11&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_71590cd787592cc916dddb5785e13f11 = L.map(
#                 &quot;map_71590cd787592cc916dddb5785e13f11&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1614fd4f78dc26b40a4126ba2357269a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_71590cd787592cc916dddb5785e13f11);
#
#
#             var feature_group_d25f582d25908c4c04a43196e03b940f = L.featureGroup(
#                 {}
#             ).addTo(map_71590cd787592cc916dddb5785e13f11);
#
#
#             var circle_marker_c25c60cb76bdd771f48e5f0f2512a9e1 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_e9c6a8f33cbbee221cbaf771bae4627c = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_53acb712c910c9fbfba9536b6e898180 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_39b8f9002576237e96ba4cc59adda36c = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_99e000af8ca094af06910b215156baf6 = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_d25f582d25908c4c04a43196e03b940f);
#
#
#             var circle_marker_df1ff4024725a7c7ee07aa397a56af57 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMous

# %%
# let's start again with a clean copy of the map of San Francisco
san_map_new = folium.Map(location=[37.77, -122.42], zoom_start=12,width='60%',height='60%')


# add incidents to map
san_map_new.add_child(incidents_markCluster)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7c48e8955cdc6311babaf1bf46f18a1 {
#                     position: relative;
#                     width: 60.0%;
#                     height: 60.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7c48e8955cdc6311babaf1bf46f18a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d7c48e8955cdc6311babaf1bf46f18a1 = L.map(
#                 &quot;map_d7c48e8955cdc6311babaf1bf46f18a1&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5ac17a75f1e2a041e53ade9ee6a2941 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d7c48e8955cdc6311babaf1bf46f18a1);
#
#
#             var marker_cluster_9b73a275e4e857ec3586aadd24adf3c8 = L.markerClusterGroup(
#                 {}
#             );
#             map_d7c48e8955cdc6311babaf1bf46f18a1.addLayer(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#             var marker_2c1e1cc6fd05feb6a26c04f9c5b42ba5 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#         var popup_237564136518f49be9676f329b1c3119 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d29a2bba34f202b3c7e210ac4608e311 = $(`&lt;div id=&quot;html_d29a2bba34f202b3c7e210ac4608e311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_237564136518f49be9676f329b1c3119.setContent(html_d29a2bba34f202b3c7e210ac4608e311);
#
#
#         marker_2c1e1cc6fd05feb6a26c04f9c5b42ba5.bindPopup(popup_237564136518f49be9676f329b1c3119)
#         ;
#
#
#
#
#             var marker_ccd4f4c6a3e73c54227581c59bc1354b = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#         var popup_9587e2b9eab795546e328593ae03c1fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e26ff14280c76cfbdc7d6760e5c6ddb4 = $(`&lt;div id=&quot;html_e26ff14280c76cfbdc7d6760e5c6ddb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#             popup_9587e2b9eab795546e328593ae03c1fd.setContent(html_e26ff14280c76cfbdc7d6760e5c6ddb4);
#
#
#         marker_ccd4f4c6a3e73c54227581c59bc1354b.bindPopup(popup_9587e2b9eab795546e328593ae03c1fd)
#         ;
#
#
#
#
#             var marker_ec86573217159b2c80681cc395b5a7c9 = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#         var popup_8f40151a91fb55c185de9bef4c870f5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ed674468ebbf79ea129c2160dd2c13a3 = $(`&lt;div id=&quot;html_ed674468ebbf79ea129c2160dd2c13a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#             popup_8f40151a91fb55c185de9bef4c870f5c.setContent(html_ed674468ebbf79ea129c2160dd2c13a3);
#
#
#         marker_ec86573217159b2c80681cc395b5a7c9.bindPopup(popup_8f40151a91fb55c185de9bef4c870f5c)
#         ;
#
#
#
#
#             var marker_1252b45cb2b38e822ecf5271a38e7c86 = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#         var popup_5ab44445abfd5645cb0a269001c66e06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_72c38d7ae661f2dbd36ac453ecd6b806 = $(`&lt;div id=&quot;html_72c38d7ae661f2dbd36ac453ecd6b806&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#             popup_5ab44445abfd5645cb0a269001c66e06.setContent(html_72c38d7ae661f2dbd36ac453ecd6b806);
#
#
#         marker_1252b45cb2b38e822ecf5271a38e7c86.bindPopup(popup_5ab44445abfd5645cb0a269001c66e06)
#         ;
#
#
#
#
#             var marker_7b303ee23bf5823c4953215d37139534 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(marker_cluster_9b73a275e4e857ec3586aadd24adf3c8);
#
#
#         var popup_7648ef92a1ae7e059bfc1ceb0da69b64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1d1e8088782bf838140758f9c78e6998 = $(`&lt;div id=&quot;ht

# %% [markdown]
# ### 以热力图的方式呈现

# %%
from folium.plugins import HeatMap

san_map = folium.Map(location=[37.77, -122.42], zoom_start=12,width='60%',height='60%')

# Convert data format
heatdata = data[['Y','X']].values.tolist()

# add incidents to map
HeatMap(heatdata).add_to(san_map)

san_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_890ae457f3e2f134bbd0200e585bdee4 {
#                     position: relative;
#                     width: 60.0%;
#                     height: 60.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_890ae457f3e2f134bbd0200e585bdee4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_890ae457f3e2f134bbd0200e585bdee4 = L.map(
#                 &quot;map_890ae457f3e2f134bbd0200e585bdee4&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0bb9b4364437ad7a3a453e239d55508 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_890ae457f3e2f134bbd0200e585bdee4);
#
#
#             var heat_map_338f5ec894f2cef156664f30db5baabf = L.heatLayer(
#                 [[37.775420706711, -122.403404791479], [37.775420706711, -122.403404791479], [37.7299809672996, -122.388856204292], [37.7857883766888, -122.412970537591], [37.7650501214668, -122.419671780296], [37.788018555829, -122.426077177375], [37.7808789360214, -122.405721454567], [37.7839805592634, -122.411778295992], [37.7757876218293, -122.393357241451], [37.7209669615499, -122.387181635995], [37.7644781578695, -122.477376524003], [37.7457389429655, -122.477960327299], [37.7356970275482, -122.37675765553], [37.7292705199592, -122.432325871028], [37.791642982384, -122.40090869889], [37.7837069301545, -122.408595110869], [37.7572895904578, -122.406870402082], [37.7489063051829, -122.420354780861], [37.715765426995, -122.439909766772], [37.7835699386918, -122.408421116922], [37.7736186276456, -122.422315670749], [37.7928412840447, -122.424519835009], [37.7540986882068, -122.414233849038], [37.7540986882068, -122.414233849038], [37.7714939969416, -122.507750131004], [37.718302204766, -122.474444639595], [37.7645752317615, -122.427562596985], [37.7874378309112, -122.419203004268], [37.7493688284532, -122.412690142308], [37.7092010462379, -122.434609280352], [37.7879209375533, -122.410882825551], [37.8004566471039, -122.401432754722], [37.7435550542265, -122.421128029505], [37.7865647607685, -122.407244087032], [37.7615655928045, -122.423803001901], [37.7615655928045, -122.423803001901], [37.7441927508932, -122.444685482273], [37.7754692820041, -122.415757039196], [37.7285280627465, -122.475647460786], [37.7428517374449, -122.420967440564], [37.7821198488931, -122.415669661443], [37.7791674218963, -122.406346425632], [37.7657184395282, -122.409529913278], [37.775420706711, -122.403404791479], [37.767524308783, -122.410738097315], [37.767524308783, -122.410738097315], [37.7131083433264, -122.444314025188], [37.7131083433264, -122.444314025188], [37.7660160114103, -122.403644620439], [37.7660160114103, -122.403644620439], [37.7762310404758, -122.414714295579], [37.7762310404758, -122.414714295579], [37.7775118895695, -122.418045452768], [37.7820238478975, -122.401161555602], [37.72700531963, -122.403408669191], [37.7838344374141, -122.412930522059], [37.7530186537446, -122.418587172219], [37.7740418385041, -122.414370627495], [37.790538993725, -122.403915681571], [37.7830998244592, -122.419183096362], [37.7407360548358, -122.388753046997], [37.7749912944366, -122.437799703468], [37.7770902743669, -122.421332684633], [37.7770902743669, -122.421332684633], [37.7822458223917, -122.446612978839], [37.7300379995128, -122.404594140634], [37.7953338267436, -122.397373740066], [37.7875158741623, -122.407434989523], [37.7785233776032, -122.403464080033], [37.7785233776032, -122.403464080033], [37.773291806903, -122.436614181331], [37.780527578509, -122.396849015172], [37.780527578509, -122.396849015172], [37.7284180706602, -122.450000790445], [37.7292114647359, -122.400834283031], [37.7880065324392, -122.399802145799], [37.7239748241609, -122.3949284758], [37.7239748241609, -122.3949284758], [37.7239748241609, -122.3949284758], [37.7883235449904, -122.41185703254], [37.7559977339856, -122.409435617106], [37.7870798144443, -122.425883358148], [37.7360374466862, -122.415126543001], [37.712767884821, -122.431928011089], [37.7895710255863, -122.402163713618], [37.7307429169559, -122.429306728376], [37.7838365565348, -122.413790972781], [37.7307429169559, -122.429306728376], [37.7373623605213, -122.422067184937], [37.7373623605213, -122.422067184937], [37.7859988323798, -122.411747371924], [37.7633758058059, -122.420434724553], [37.7850226622786, -122.411987643595], [37.7746206491065, -122.500380427915], [37.7751918267217, -122.466558780683], [37.7490841729028, -122.486925960114], [37.7685360123583, -122.41561633832], [37.7644297714074, -122.449751652563], [37.7644297714074, -122.449751652563], [37.7352681469084, -122.472715759631], [37.7592805524173, -122.488120173893], [37.7555043420028, -122.417660640341], [37.7853906306613, -122.4010277 ...
