# %%
import os
import sys

from PIL import Image

import torch
import torchvision

from torchvision import transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

# %%
# # 向 sys.path 中临时添加模块文件存储位置的完整路径
cwd = os.getcwd()
sys.path.append(os.path.join(cwd, "vision", "references", "detection"))

# %%
from engine import train_one_epoch, evaluate
import utils

# %% [markdown]
# <br>
# <br>

# %%
class PennFudanDataset(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images and masks
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = Image.open(img_path).convert("RGB")
        # note that we haven't converted the mask to RGB,
        # because each color corresponds to a different instance
        # with 0 being background
        mask = Image.open(mask_path)

        mask = np.array(mask)
        # instances are encoded as different colors
        obj_ids = np.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]

        # split the color-encoded mask into a set
        # of binary masks
        masks = mask == obj_ids[:, None, None]

        # get bounding box coordinates for each mask
        num_objs = len(obj_ids)
        boxes = []
        for i in range(num_objs):
            pos = np.where(masks[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])

        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        masks = torch.as_tensor(masks, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            # img, target = self.transforms(img, target)
            img = self.transforms(img)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# <br>
# <br>

# %%
def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask,
                                                       hidden_layer,
                                                       num_classes)

    return model

# %% [markdown]
# <br>
# <br>

# %%
from torchvision.transforms import functional as F
from torch import Tensor

from typing import List, Tuple, Dict, Optional, Union

class MyRandomHorizontalFlip(transforms.RandomHorizontalFlip):
    def forward(self, 
                image: Tensor, 
                target: Optional[Dict[str, Tensor]] = None
                ) -> Tuple[Tensor, Optional[Dict[str, Tensor]]]:
        
        if torch.rand(1) < self.p:
            image = F.hflip(image)
            if target is not None:
                _, _, width = F.get_dimensions(image)
                target["boxes"][:, [0, 2]] = width - target["boxes"][:, [2, 0]]
                if "masks" in target:
                    target["masks"] = target["masks"].flip(-1)
                if "keypoints" in target:
                    keypoints = target["keypoints"]
                    keypoints = _flip_coco_person_keypoints(keypoints, width)
                    target["keypoints"] = keypoints
        return image, target

# %% [markdown]
# <br>

# %%
class Compose(object):
    def __init__(self, transforms):
        self.transforms = transforms

    # def __call__(self, image, target):
    def __call__(self, image):
        for t in self.transforms:
            if isinstance(image, tuple):
                image = image[0]
            image = t(image)
            
            """
            if i==0: 
                continue;
            for k, v in target.items():
                target[k] = t(v)
                # target[k] = t(transforms.ToPILImage(v))   
                # 原始的 v 都是 Tensor，需要使用 transforms.ToPILImage() 方法 进行转换，
                # 否则会报错 TypeError: Tensor is not a torch image.
            
            # target = t(target)
            # 上面这一句会报错：TypeError: img should be PIL Image. Got <class 'dict'>
            # 解决方法参考自：
            # https://python.iitter.com/other/105872.html
            """
        return image#, target

# %%
def get_transform(train):
    my_transforms = []
    # my_transforms.append(transforms.ToPILImage())
    
    if train:
        my_transforms.append(MyRandomHorizontalFlip(0.5))
    
    my_transforms.append(transforms.ToTensor())
    # Toensor() 要放到最后，详见：
    # https://discuss.pytorch.org/t/t-compose-typeerror-call-takes-2-positional-arguments-but-3-were-given/62529
    # https://python.iitter.com/other/105872.html
    
    return Compose(my_transforms)

# %% [markdown]
# <br>
# <br>
# <br>

# %%
def main():
    # train on the GPU or on the CPU, if a GPU is not available
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

    # our dataset has two classes only - background and person
    num_classes = 2
    # use our dataset and defined transformations
    dataset = PennFudanDataset('./data/PennFudanPed', get_transform(train=True))
    dataset_test = PennFudanDataset('./data/PennFudanPed', get_transform(train=False))

    # split the dataset in train and test set
    indices = torch.randperm(len(dataset)).tolist()
    dataset = torch.utils.data.Subset(dataset, indices[:-50])
    dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

    # define training and validation data loaders
    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=2, shuffle=True, num_workers=0,
        collate_fn=utils.collate_fn)

    data_loader_test = torch.utils.data.DataLoader(
        dataset_test, batch_size=1, shuffle=False, num_workers=0,
        collate_fn=utils.collate_fn)

    # get the model using our helper function
    model = get_model_instance_segmentation(num_classes)

    # move model to the right device
    model.to(device)

    # construct an optimizer
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.SGD(params, lr=0.005,
                                momentum=0.9, weight_decay=0.0005)
    # and a learning rate scheduler
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                                   step_size=3,
                                                   gamma=0.1)

    # let's train it for 10 epochs
    num_epochs = 10

    for epoch in range(num_epochs):
        # train for one epoch, printing every 10 iterations
        train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
        # update the learning rate
        lr_scheduler.step()
        # evaluate on the test dataset
        evaluate(model, data_loader_test, device=device)

    print("That's it!")

# %%
main()
# Out:
# D:\Programs\Anaconda3\envs\ptg\lib\site-packages\torch\functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ..\aten\src\ATen\native\TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Epoch: [0]  [ 0/60]  eta: 0:04:35  lr: 0.000090  loss: 3.3705 (3.3705)  loss_classifier: 0.9240 (0.9240)  loss_box_reg: 0.2794 (0.2794)  loss_mask: 2.1456 (2.1456)  loss_objectness: 0.0167 (0.0167)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 4.5896  data: 0.0190  max mem: 2135
# Epoch: [0]  [10/60]  eta: 0:00:40  lr: 0.000936  loss: 2.3859 (2.4675)  loss_classifier: 0.5348 (0.5664)  loss_box_reg: 0.1756 (0.1972)  loss_mask: 1.4276 (1.6468)  loss_objectness: 0.0533 (0.0486)  loss_rpn_box_reg: 0.0055 (0.0084)  time: 0.8026  data: 0.0200  max mem: 3876
# Epoch: [0]  [20/60]  eta: 0:00:24  lr: 0.001783  loss: 1.1219 (1.7532)  loss_classifier: 0.1936 (0.3668)  loss_box_reg: 0.1637 (0.1818)  loss_mask: 0.8076 (1.1399)  loss_objectness: 0.0319 (0.0509)  loss_rpn_box_reg: 0.0095 (0.0139)  time: 0.4248  data: 0.0197  max mem: 3876
# Epoch: [0]  [30/60]  eta: 0:00:16  lr: 0.002629  loss: 0.8934 (1.4774)  loss_classifier: 0.1221 (0.2889)  loss_box_reg: 0.1686 (0.1841)  loss_mask: 0.4902 (0.9512)  loss_objectness: 0.0188 (0.0392)  loss_rpn_box_reg: 0.0139 (0.0139)  time: 0.4190  data: 0.0191  max mem: 3876
# Epoch: [0]  [40/60]  eta: 0:00:10  lr: 0.003476  loss: 0.8863 (1.3256)  loss_classifier: 0.1129 (0.2452)  loss_box_reg: 0.1928 (0.1826)  loss_mask: 0.5585 (0.8506)  loss_objectness: 0.0161 (0.0335)  loss_rpn_box_reg: 0.0139 (0.0137)  time: 0.4142  data: 0.0198  max mem: 3876
# Epoch: [0]  [50/60]  eta: 0:00:04  lr: 0.004323  loss: 0.8206 (1.2363)  loss_classifier: 0.1129 (0.2217)  loss_box_reg: 0.1712 (0.1873)  loss_mask: 0.5400 (0.7847)  loss_objectness: 0.0140 (0.0291)  loss_rpn_box_reg: 0.0104 (0.0135)  time: 0.4120  data: 0.0209  max mem: 3876
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.7981 (1.1688)  loss_classifier: 0.1159 (0.2045)  loss_box_reg: 0.2039 (0.1905)  loss_mask: 0.4676 (0.7344)  loss_objectness: 0.0099 (0.0262)  loss_rpn_box_reg: 0.0088 (0.0131)  time: 0.4100  data: 0.0215  max mem: 3876
# Epoch: [0] Total time: 0:00:29 (0.4847 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:07  model_time: 0.1200 (0.1200)  evaluator_time: 0.0220 (0.0220)  time: 0.1500  data: 0.0080  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.1200 (0.1285)  evaluator_time: 0.0260 (0.0329)  time: 0.1775  data: 0.0116  max mem: 3876
# Test: Total time: 0:00:08 (0.1740 s / it)
# Averaged stats: model_time: 0.1200 (0.1285)  evaluator_time: 0.0260 (0.0329)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.926
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.444
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.246
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.538
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.225
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.582
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.320
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.446
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.623
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.936
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.287
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.265
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.677
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.480
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.638
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.690
# Epoch: [1]  [ 0/60]  eta: 0:00:30  lr: 0.005000  loss: 1.2661 (1.2661)  loss_classifier: 0.1669 (0.1669)  loss_box_reg: 0.2649 (0.2649)  loss_mask: 0.7706 (0.7706)  loss_objectness: 0.0461 (0.0461)  loss_rpn_box_reg: 0.0175 (0.0175)  time: 0.5003  data: 0.0200  max mem: 3876
# Epoch: [1]  [10/60]  eta: 0:00:21  lr: 0.005000  loss: 0.7369 (0.7669)  loss_classifier: 0.0941 (0.0998)  loss_box_reg: 0.1916 (0.2004)  loss_mask: 0.3462 (0.4427)  loss_objectness: 0.0072 (0.0137)  loss_rpn_box_reg: 0.0074 (0.0103)  time: 0.4341  data: 0.0178  max mem: 3876
# Epoch: [1]  [20/60]  eta: 0:00:17  lr: 0.005000  loss: 0.5724 (0.7440)  loss_classifier: 0.0783 (0.0989)  loss_box_reg: 0.1529 (0.1770)  loss_mask: 0.3292 (0.4471)  loss_objectness: 0.0057 (0.0114)  loss_rpn_box_reg: 0.0072 (0.0097)  time: 0.4234  data: 0.0196  max mem: 3876
# Epoch: [1]  [30/60]  eta: 0:00:12  lr: 0.005000  loss: 0.6397 (0.7347)  loss_classifier: 0.0747 (0.0953)  loss_box_reg: 0.1173 (0.1563)  loss_mask: 0.4552 (0.4622)  loss_objectness: 0.0059 (0.0115)  loss_rpn_box_reg: 0.0071 (0.0094)  time: 0.4131  data: 0.0203  max mem: 3876
# Epoch: [1]  [40/60]  eta: 0:00:08  lr: 0.005000  loss: 0.7033 (0.7221)  loss_classifier: 0.0782 (0.0954)  loss_box_reg: 0.1102 (0.1524)  loss_mask: 0.4552 (0.4539)  loss_objectness: 0.0073 (0.0111)  loss_rpn_box_reg: 0.0077 (0.0092)  time: 0.4049  data: 0.0193  max mem: 3876
# Epoch: [1]  [50/60]  eta: 0:00:04  lr: 0.005000  loss: 0.5982 (0.6929)  loss_classifier: 0.0883 (0.0932)  loss_box_reg: 0.1154 (0.1427)  loss_mask: 0.3654 (0.4361)  loss_objectness: 0.0071 (0.0111)  loss_rpn_box_reg: 0.0084 (0.0099)  time: 0.4089  data: 0.0187  max mem: 3876
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.6015 (0.7208)  loss_classifier: 0.0937 (0.0975)  loss_box_reg: 0.1060 (0.1497)  loss_mask: 0.3727 (0.4524)  loss_objectness: 0.0076 (0.0106)  loss_rpn_box_reg: 0.0078 (0.0106)  time: 0.4251  data: 0.0190  max mem: 3876
# Epoch: [1] Total time: 0:00:25 (0.4206 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0950 (0.0950)  evaluator_time: 0.0130 (0.0130)  time: 0.1160  data: 0.0080  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0950 (0.1009)  evaluator_time: 0.0130 (0.0168)  time: 0.1327  data: 0.0116  max mem: 3876
# Test: Total time: 0:00:06 (0.1306 s / it)
# Averaged stats: model_time: 0.0950 (0.1009)  evaluator_time: 0.0130 (0.0168)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.943
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.945
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.347
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.411
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.685
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
# Epoch: [2]  [ 0/60]  eta: 0:00:28  lr: 0.005000  loss: 0.4179 (0.4179)  loss_classifier: 0.0469 (0.0469)  loss_box_reg: 0.0581 (0.0581)  loss_mask: 0.3038 (0.3038)  loss_objectness: 0.0077 (0.0077)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 0.4735  data: 0.0210  max mem: 3876
# Epoch: [2]  [10/60]  eta: 0:00:23  lr: 0.005000  loss: 0.6155 (0.6781)  loss_classifier: 0.0716 (0.0899)  loss_box_reg: 0.0999 (0.1353)  loss_mask: 0.3772 (0.4318)  loss_objectness: 0.0077 (0.0096)  loss_rpn_box_reg: 0.0074 (0.0116)  time: 0.4651  data: 0.0213  max mem: 3876
# Epoch: [2]  [20/60]  eta: 0:00:17  lr: 0.005000  loss: 0.5891 (0.6083)  loss_classifier: 0.0716 (0.0825)  loss_box_reg: 0.0940 (0.1203)  loss_mask: 0.3715 (0.3880)  loss_objectness: 0.0048 (0.0080)  loss_rpn_box_reg: 0.0068 (0.0095)  time: 0.4394  data: 0.0199  max mem: 3876
# Epoch: [2]  [30/60]  eta: 0:00:13  lr: 0.005000  loss: 0.5665 (0.6430)  loss_classifier: 0.0675 (0.0906)  loss_box_reg: 0.0940 (0.1310)  loss_mask: 0.3653 (0.4023)  loss_objectness: 0.0060 (0.0090)  loss_rpn_box_reg: 0.0081 (0.0100)  time: 0.4229  data: 0.0197  max mem: 3876
# Epoch: [2]  [40/60]  eta: 0:00:08  lr: 0.005000  loss: 0.6451 (0.6363)  loss_classifier: 0.0806 (0.0885)  loss_box_reg: 0.1139 (0.1270)  loss_mask: 0.3993 (0.4012)  loss_objectness: 0.0088 (0.0100)  loss_rpn_box_reg: 0.0087 (0.0098)  time: 0.4122  data: 0.0204  max mem: 3876
# Epoch: [2]  [50/60]  eta: 0:00:04  lr: 0.005000  loss: 0.6451 (0.6500)  loss_classifier: 0.0853 (0.0895)  loss_box_reg: 0.1139 (0.1311)  loss_mask: 0.3752 (0.4106)  loss_objectness: 0.0070 (0.0089)  loss_rpn_box_reg: 0.0086 (0.0100)  time: 0.3999  data: 0.0211  max mem: 3876
# Epoch: [2]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.6388 (0.6598)  loss_classifier: 0.0988 (0.0904)  loss_box_reg: 0.0957 (0.1299)  loss_mask: 0.4631 (0.4198)  loss_objectness: 0.0051 (0.0097)  loss_rpn_box_reg: 0.0089 (0.0099)  time: 0.4047  data: 0.0202  max mem: 3876
# Epoch: [2] Total time: 0:00:25 (0.4210 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.1000 (0.1000)  evaluator_time: 0.0100 (0.0100)  time: 0.1200  data: 0.0100  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0970 (0.1010)  evaluator_time: 0.0140 (0.0169)  time: 0.1326  data: 0.0114  max mem: 3876
# Test: Total time: 0:00:06 (0.1302 s / it)
# Averaged stats: model_time: 0.0970 (0.1010)  evaluator_time: 0.0140 (0.0169)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.957
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.813
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.295
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.739
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.669
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.765
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.666
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.958
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.691
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.726
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.745
# Epoch: [3]  [ 0/60]  eta: 0:00:22  lr: 0.000500  loss: 0.6072 (0.6072)  loss_classifier: 0.0844 (0.0844)  loss_box_reg: 0.1190 (0.1190)  loss_mask: 0.3948 (0.3948)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 0.3741  data: 0.0200  max mem: 3876
# Epoch: [3]  [10/60]  eta: 0:00:22  lr: 0.000500  loss: 0.5909 (0.6198)  loss_classifier: 0.0893 (0.0959)  loss_box_reg: 0.1407 (0.1292)  loss_mask: 0.3531 (0.3768)  loss_objectness: 0.0065 (0.0074)  loss_rpn_box_reg: 0.0094 (0.0105)  time: 0.4579  data: 0.0240  max mem: 3876
# Epoch: [3]  [20/60]  eta: 0:00:17  lr: 0.000500  loss: 0.5733 (0.6206)  loss_classifier: 0.0853 (0.0870)  loss_box_reg: 0.1045 (0.1150)  loss_mask: 0.3666 (0.4021)  loss_objectness: 0.0049 (0.0070)  loss_rpn_box_reg: 0.0084 (0.0095)  time: 0.4449  data: 0.0217  max mem: 3876
# Epoch: [3]  [30/60]  eta: 0:00:12  lr: 0.000500  loss: 0.5733 (0.6366)  loss_classifier: 0.0732 (0.0842)  loss_box_reg: 0.0766 (0.1111)  loss_mask: 0.4385 (0.4247)  loss_objectness: 0.0061 (0.0077)  loss_rpn_box_reg: 0.0078 (0.0089)  time: 0.4043  data: 0.0184  max mem: 3876
# Epoch: [3]  [40/60]  eta: 0:00:08  lr: 0.000500  loss: 0.5318 (0.6064)  loss_classifier: 0.0639 (0.0808)  loss_box_reg: 0.0727 (0.1030)  loss_mask: 0.3762 (0.4070)  loss_objectness: 0.0056 (0.0072)  loss_rpn_box_reg: 0.0075 (0.0084)  time: 0.4077  data: 0.0179  max mem: 3876
# Epoch: [3]  [50/60]  eta: 0:00:04  lr: 0.000500  loss: 0.5328 (0.6188)  loss_classifier: 0.0714 (0.0836)  loss_box_reg: 0.0756 (0.1059)  loss_mask: 0.3686 (0.4141)  loss_objectness: 0.0046 (0.0069)  loss_rpn_box_reg: 0.0075 (0.0083)  time: 0.4155  data: 0.0183  max mem: 3876
# Epoch: [3]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.5264 (0.6015)  loss_classifier: 0.0818 (0.0834)  loss_box_reg: 0.1018 (0.1053)  loss_mask: 0.3139 (0.3981)  loss_objectness: 0.0045 (0.0069)  loss_rpn_box_reg: 0.0056 (0.0079)  time: 0.4094  data: 0.0199  max mem: 3876
# Epoch: [3] Total time: 0:00:25 (0.4191 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0900 (0.0900)  evaluator_time: 0.0100 (0.0100)  time: 0.1100  data: 0.0100  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0910 (0.0969)  evaluator_time: 0.0110 (0.0140)  time: 0.1244  data: 0.0112  max mem: 3876
# Test: Total time: 0:00:06 (0.1229 s / it)
# Averaged stats: model_time: 0.0910 (0.0969)  evaluator_time: 0.0110 (0.0140)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.732
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.960
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.851
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.597
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.305
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.774
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.810
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.687
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.842
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.388
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.713
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.277
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.726
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.754
# Epoch: [4]  [ 0/60]  eta: 0:00:19  lr: 0.000500  loss: 0.5172 (0.5172)  loss_classifier: 0.0610 (0.0610)  loss_box_reg: 0.0715 (0.0715)  loss_mask: 0.3783 (0.3783)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 0.3263  data: 0.0140  max mem: 3876
# Epoch: [4]  [10/60]  eta: 0:00:21  lr: 0.000500  loss: 0.7057 (0.6765)  loss_classifier: 0.1000 (0.1021)  loss_box_reg: 0.1082 (0.1324)  loss_mask: 0.4238 (0.4223)  loss_objectness: 0.0071 (0.0093)  loss_rpn_box_reg: 0.0100 (0.0103)  time: 0.4201  data: 0.0236  max mem: 3876
# Epoch: [4]  [20/60]  eta: 0:00:16  lr: 0.000500  loss: 0.5175 (0.5991)  loss_classifier: 0.0801 (0.0881)  loss_box_reg: 0.0897 (0.1146)  loss_mask: 0.3383 (0.3802)  loss_objectness: 0.0069 (0.0081)  loss_rpn_box_reg: 0.0043 (0.0080)  time: 0.4092  data: 0.0216  max mem: 3876
# Epoch: [4]  [30/60]  eta: 0:00:12  lr: 0.000500  loss: 0.5175 (0.5829)  loss_classifier: 0.0668 (0.0834)  loss_box_reg: 0.0731 (0.1097)  loss_mask: 0.3383 (0.3753)  loss_objectness: 0.0041 (0.0069)  loss_rpn_box_reg: 0.0054 (0.0076)  time: 0.3989  data: 0.0207  max mem: 3876
# Epoch: [4]  [40/60]  eta: 0:00:08  lr: 0.000500  loss: 0.5561 (0.6123)  loss_classifier: 0.0843 (0.0888)  loss_box_reg: 0.0975 (0.1152)  loss_mask: 0.3989 (0.3935)  loss_objectness: 0.0040 (0.0070)  loss_rpn_box_reg: 0.0060 (0.0078)  time: 0.4193  data: 0.0203  max mem: 3876
# Epoch: [4]  [50/60]  eta: 0:00:04  lr: 0.000500  loss: 0.6539 (0.6230)  loss_classifier: 0.0933 (0.0910)  loss_box_reg: 0.1127 (0.1169)  loss_mask: 0.4286 (0.3999)  loss_objectness: 0.0026 (0.0068)  loss_rpn_box_reg: 0.0057 (0.0084)  time: 0.4315  data: 0.0188  max mem: 3876
# Epoch: [4]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.6129 (0.6295)  loss_classifier: 0.0836 (0.0902)  loss_box_reg: 0.0682 (0.1171)  loss_mask: 0.4286 (0.4064)  loss_objectness: 0.0030 (0.0074)  loss_rpn_box_reg: 0.0077 (0.0085)  time: 0.4162  data: 0.0179  max mem: 3876
# Epoch: [4] Total time: 0:00:24 (0.4140 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0920 (0.0920)  evaluator_time: 0.0120 (0.0120)  time: 0.1110  data: 0.0070  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0930 (0.0973)  evaluator_time: 0.0110 (0.0143)  time: 0.1268  data: 0.0111  max mem: 3876
# Test: Total time: 0:00:06 (0.1239 s / it)
# Averaged stats: model_time: 0.0930 (0.0973)  evaluator_time: 0.0110 (0.0143)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.728
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.952
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.860
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.310
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.797
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.817
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.684
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.954
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.371
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.485
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.284
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.760
# Epoch: [5]  [ 0/60]  eta: 0:00:27  lr: 0.000500  loss: 0.5740 (0.5740)  loss_classifier: 0.0738 (0.0738)  loss_box_reg: 0.0751 (0.0751)  loss_mask: 0.4205 (0.4205)  loss_objectness: 0.0008 (0.0008)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 0.4625  data: 0.0200  max mem: 3876
# Epoch: [5]  [10/60]  eta: 0:00:20  lr: 0.000500  loss: 0.5329 (0.5312)  loss_classifier: 0.0808 (0.0749)  loss_box_reg: 0.0778 (0.0920)  loss_mask: 0.3528 (0.3518)  loss_objectness: 0.0031 (0.0043)  loss_rpn_box_reg: 0.0051 (0.0083)  time: 0.4181  data: 0.0191  max mem: 3876
# Epoch: [5]  [20/60]  eta: 0:00:17  lr: 0.000500  loss: 0.5230 (0.5701)  loss_classifier: 0.0808 (0.0824)  loss_box_reg: 0.0778 (0.1086)  loss_mask: 0.3367 (0.3655)  loss_objectness: 0.0042 (0.0050)  loss_rpn_box_reg: 0.0060 (0.0086)  time: 0.4374  data: 0.0209  max mem: 3876
# Epoch: [5]  [30/60]  eta: 0:00:12  lr: 0.000500  loss: 0.5402 (0.5886)  loss_classifier: 0.0884 (0.0857)  loss_box_reg: 0.1058 (0.1087)  loss_mask: 0.3240 (0.3804)  loss_objectness: 0.0055 (0.0058)  loss_rpn_box_reg: 0.0069 (0.0079)  time: 0.4406  data: 0.0206  max mem: 3876
# Epoch: [5]  [40/60]  eta: 0:00:08  lr: 0.000500  loss: 0.4908 (0.5577)  loss_classifier: 0.0735 (0.0828)  loss_box_reg: 0.0979 (0.1043)  loss_mask: 0.2746 (0.3573)  loss_objectness: 0.0029 (0.0056)  loss_rpn_box_reg: 0.0066 (0.0075)  time: 0.4236  data: 0.0189  max mem: 3876
# Epoch: [5]  [50/60]  eta: 0:00:04  lr: 0.000500  loss: 0.3694 (0.5433)  loss_classifier: 0.0643 (0.0817)  loss_box_reg: 0.0623 (0.1002)  loss_mask: 0.2334 (0.3488)  loss_objectness: 0.0043 (0.0057)  loss_rpn_box_reg: 0.0035 (0.0070)  time: 0.4184  data: 0.0187  max mem: 3876
# Epoch: [5]  [59/60]  eta: 0:00:00  lr: 0.000500  loss: 0.4566 (0.5722)  loss_classifier: 0.0718 (0.0846)  loss_box_reg: 0.0808 (0.1066)  loss_mask: 0.3669 (0.3677)  loss_objectness: 0.0051 (0.0059)  loss_rpn_box_reg: 0.0051 (0.0074)  time: 0.4089  data: 0.0182  max mem: 3876
# Epoch: [5] Total time: 0:00:25 (0.4230 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0894 (0.0894)  evaluator_time: 0.0090 (0.0090)  time: 0.1084  data: 0.0100  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0890 (0.0964)  evaluator_time: 0.0100 (0.0136)  time: 0.1233  data: 0.0122  max mem: 3876
# Test: Total time: 0:00:06 (0.1222 s / it)
# Averaged stats: model_time: 0.0890 (0.0964)  evaluator_time: 0.0100 (0.0136)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.739
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.776
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.810
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.702
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.963
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.865
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.386
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.485
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.731
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.742
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.756
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.768
# Epoch: [6]  [ 0/60]  eta: 0:00:29  lr: 0.000050  loss: 1.0509 (1.0509)  loss_classifier: 0.1322 (0.1322)  loss_box_reg: 0.2038 (0.2038)  loss_mask: 0.6973 (0.6973)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0110 (0.0110)  time: 0.4960  data: 0.0280  max mem: 3876
# Epoch: [6]  [10/60]  eta: 0:00:21  lr: 0.000050  loss: 0.7088 (0.6590)  loss_classifier: 0.0817 (0.0918)  loss_box_reg: 0.1038 (0.1315)  loss_mask: 0.4201 (0.4203)  loss_objectness: 0.0067 (0.0052)  loss_rpn_box_reg: 0.0086 (0.0101)  time: 0.4316  data: 0.0220  max mem: 3876
# Epoch: [6]  [20/60]  eta: 0:00:16  lr: 0.000050  loss: 0.6236 (0.6687)  loss_classifier: 0.0817 (0.0956)  loss_box_reg: 0.0874 (0.1301)  loss_mask: 0.3929 (0.4265)  loss_objectness: 0.0068 (0.0067)  loss_rpn_box_reg: 0.0066 (0.0098)  time: 0.4066  data: 0.0189  max mem: 3876
# Epoch: [6]  [30/60]  eta: 0:00:12  lr: 0.000050  loss: 0.5877 (0.6551)  loss_classifier: 0.0726 (0.0909)  loss_box_reg: 0.0874 (0.1233)  loss_mask: 0.3929 (0.4250)  loss_objectness: 0.0061 (0.0070)  loss_rpn_box_reg: 0.0061 (0.0088)  time: 0.4042  data: 0.0178  max mem: 3876
# Epoch: [6]  [40/60]  eta: 0:00:08  lr: 0.000050  loss: 0.5501 (0.6243)  loss_classifier: 0.0686 (0.0898)  loss_box_reg: 0.0885 (0.1158)  loss_mask: 0.3500 (0.4037)  loss_objectness: 0.0038 (0.0068)  loss_rpn_box_reg: 0.0040 (0.0081)  time: 0.4285  data: 0.0199  max mem: 3876
# Epoch: [6]  [50/60]  eta: 0:00:04  lr: 0.000050  loss: 0.4991 (0.6063)  loss_classifier: 0.0733 (0.0873)  loss_box_reg: 0.0863 (0.1131)  loss_mask: 0.3337 (0.3917)  loss_objectness: 0.0038 (0.0064)  loss_rpn_box_reg: 0.0046 (0.0078)  time: 0.4214  data: 0.0207  max mem: 3876
# Epoch: [6]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.4274 (0.5936)  loss_classifier: 0.0715 (0.0861)  loss_box_reg: 0.0863 (0.1106)  loss_mask: 0.3083 (0.3833)  loss_objectness: 0.0038 (0.0061)  loss_rpn_box_reg: 0.0055 (0.0074)  time: 0.4171  data: 0.0214  max mem: 3876
# Epoch: [6] Total time: 0:00:25 (0.4180 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0840 (0.0840)  evaluator_time: 0.0090 (0.0090)  time: 0.1010  data: 0.0080  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0914 (0.0964)  evaluator_time: 0.0100 (0.0131)  time: 0.1236  data: 0.0110  max mem: 3876
# Test: Total time: 0:00:06 (0.1218 s / it)
# Averaged stats: model_time: 0.0914 (0.0964)  evaluator_time: 0.0100 (0.0131)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.747
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.579
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.781
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.317
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.825
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.704
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.873
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.480
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.733
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.291
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.758
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# Epoch: [7]  [ 0/60]  eta: 0:00:21  lr: 0.000050  loss: 0.2466 (0.2466)  loss_classifier: 0.0345 (0.0345)  loss_box_reg: 0.0292 (0.0292)  loss_mask: 0.1787 (0.1787)  loss_objectness: 0.0033 (0.0033)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.3650  data: 0.0220  max mem: 3876
# Epoch: [7]  [10/60]  eta: 0:00:21  lr: 0.000050  loss: 0.3899 (0.5003)  loss_classifier: 0.0737 (0.0798)  loss_box_reg: 0.0903 (0.1019)  loss_mask: 0.2452 (0.3061)  loss_objectness: 0.0034 (0.0053)  loss_rpn_box_reg: 0.0069 (0.0072)  time: 0.4364  data: 0.0207  max mem: 3876
# Epoch: [7]  [20/60]  eta: 0:00:17  lr: 0.000050  loss: 0.5554 (0.5706)  loss_classifier: 0.0852 (0.0866)  loss_box_reg: 0.0919 (0.1093)  loss_mask: 0.3695 (0.3601)  loss_objectness: 0.0045 (0.0059)  loss_rpn_box_reg: 0.0077 (0.0087)  time: 0.4366  data: 0.0208  max mem: 3876
# Epoch: [7]  [30/60]  eta: 0:00:12  lr: 0.000050  loss: 0.5496 (0.5440)  loss_classifier: 0.0778 (0.0835)  loss_box_reg: 0.0892 (0.1065)  loss_mask: 0.3684 (0.3410)  loss_objectness: 0.0045 (0.0053)  loss_rpn_box_reg: 0.0058 (0.0077)  time: 0.4270  data: 0.0196  max mem: 3876
# Epoch: [7]  [40/60]  eta: 0:00:08  lr: 0.000050  loss: 0.4563 (0.5673)  loss_classifier: 0.0683 (0.0837)  loss_box_reg: 0.0693 (0.1072)  loss_mask: 0.3091 (0.3631)  loss_objectness: 0.0034 (0.0053)  loss_rpn_box_reg: 0.0048 (0.0079)  time: 0.4170  data: 0.0194  max mem: 3876
# Epoch: [7]  [50/60]  eta: 0:00:04  lr: 0.000050  loss: 0.5493 (0.5737)  loss_classifier: 0.0801 (0.0842)  loss_box_reg: 0.0897 (0.1070)  loss_mask: 0.4016 (0.3691)  loss_objectness: 0.0048 (0.0057)  loss_rpn_box_reg: 0.0069 (0.0076)  time: 0.4185  data: 0.0213  max mem: 3876
# Epoch: [7]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.5493 (0.5828)  loss_classifier: 0.0775 (0.0840)  loss_box_reg: 0.0724 (0.1088)  loss_mask: 0.4016 (0.3764)  loss_objectness: 0.0058 (0.0060)  loss_rpn_box_reg: 0.0061 (0.0076)  time: 0.4173  data: 0.0204  max mem: 3876
# Epoch: [7] Total time: 0:00:25 (0.4246 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:05  model_time: 0.0840 (0.0840)  evaluator_time: 0.0090 (0.0090)  time: 0.1010  data: 0.0070  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0890 (0.0961)  evaluator_time: 0.0100 (0.0135)  time: 0.1241  data: 0.0109  max mem: 3876
# Test: Total time: 0:00:06 (0.1221 s / it)
# Averaged stats: model_time: 0.0890 (0.0961)  evaluator_time: 0.0100 (0.0135)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.861
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.574
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.314
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.787
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.802
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.824
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.962
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.881
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.366
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.477
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.747
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.772
# Epoch: [8]  [ 0/60]  eta: 0:00:29  lr: 0.000050  loss: 0.8140 (0.8140)  loss_classifier: 0.1670 (0.1670)  loss_box_reg: 0.2430 (0.2430)  loss_mask: 0.3704 (0.3704)  loss_objectness: 0.0068 (0.0068)  loss_rpn_box_reg: 0.0269 (0.0269)  time: 0.4951  data: 0.0390  max mem: 3876
# Epoch: [8]  [10/60]  eta: 0:00:21  lr: 0.000050  loss: 0.5692 (0.5615)  loss_classifier: 0.0799 (0.0870)  loss_box_reg: 0.0995 (0.1068)  loss_mask: 0.3464 (0.3502)  loss_objectness: 0.0033 (0.0084)  loss_rpn_box_reg: 0.0074 (0.0090)  time: 0.4209  data: 0.0211  max mem: 3876
# Epoch: [8]  [20/60]  eta: 0:00:17  lr: 0.000050  loss: 0.5044 (0.4889)  loss_classifier: 0.0782 (0.0809)  loss_box_reg: 0.0832 (0.0897)  loss_mask: 0.2874 (0.3040)  loss_objectness: 0.0031 (0.0065)  loss_rpn_box_reg: 0.0048 (0.0077)  time: 0.4243  data: 0.0196  max mem: 3876
# Epoch: [8]  [30/60]  eta: 0:00:12  lr: 0.000050  loss: 0.4920 (0.5283)  loss_classifier: 0.0735 (0.0822)  loss_box_reg: 0.0681 (0.0969)  loss_mask: 0.2721 (0.3359)  loss_objectness: 0.0031 (0.0060)  loss_rpn_box_reg: 0.0037 (0.0074)  time: 0.4171  data: 0.0197  max mem: 3876
# Epoch: [8]  [40/60]  eta: 0:00:08  lr: 0.000050  loss: 0.4396 (0.5029)  loss_classifier: 0.0627 (0.0759)  loss_box_reg: 0.0681 (0.0899)  loss_mask: 0.2768 (0.3254)  loss_objectness: 0.0015 (0.0051)  loss_rpn_box_reg: 0.0035 (0.0066)  time: 0.4055  data: 0.0183  max mem: 3876
# Epoch: [8]  [50/60]  eta: 0:00:04  lr: 0.000050  loss: 0.4066 (0.5247)  loss_classifier: 0.0659 (0.0780)  loss_box_reg: 0.0770 (0.0968)  loss_mask: 0.2739 (0.3380)  loss_objectness: 0.0026 (0.0055)  loss_rpn_box_reg: 0.0043 (0.0065)  time: 0.4272  data: 0.0205  max mem: 3876
# Epoch: [8]  [59/60]  eta: 0:00:00  lr: 0.000050  loss: 0.4179 (0.5250)  loss_classifier: 0.0733 (0.0778)  loss_box_reg: 0.0884 (0.0963)  loss_mask: 0.2781 (0.3384)  loss_objectness: 0.0057 (0.0055)  loss_rpn_box_reg: 0.0067 (0.0070)  time: 0.4209  data: 0.0207  max mem: 3876
# Epoch: [8] Total time: 0:00:25 (0.4192 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:04  model_time: 0.0792 (0.0792)  evaluator_time: 0.0100 (0.0100)  time: 0.0962  data: 0.0070  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0903 (0.0967)  evaluator_time: 0.0100 (0.0133)  time: 0.1257  data: 0.0117  max mem: 3876
# Test: Total time: 0:00:06 (0.1226 s / it)
# Averaged stats: model_time: 0.0903 (0.0967)  evaluator_time: 0.0100 (0.0133)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.753
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.582
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.706
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.963
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.367
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.770
# Epoch: [9]  [ 0/60]  eta: 0:00:20  lr: 0.000005  loss: 0.4679 (0.4679)  loss_classifier: 0.0692 (0.0692)  loss_box_reg: 0.0390 (0.0390)  loss_mask: 0.3543 (0.3543)  loss_objectness: 0.0029 (0.0029)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 0.3430  data: 0.0180  max mem: 3876
# Epoch: [9]  [10/60]  eta: 0:00:21  lr: 0.000005  loss: 0.5263 (0.5750)  loss_classifier: 0.0791 (0.0835)  loss_box_reg: 0.0879 (0.1038)  loss_mask: 0.3543 (0.3757)  loss_objectness: 0.0019 (0.0042)  loss_rpn_box_reg: 0.0090 (0.0078)  time: 0.4339  data: 0.0217  max mem: 3876
# Epoch: [9]  [20/60]  eta: 0:00:16  lr: 0.000005  loss: 0.5154 (0.5412)  loss_classifier: 0.0791 (0.0769)  loss_box_reg: 0.0826 (0.0960)  loss_mask: 0.3223 (0.3572)  loss_objectness: 0.0037 (0.0049)  loss_rpn_box_reg: 0.0057 (0.0061)  time: 0.4213  data: 0.0199  max mem: 3876
# Epoch: [9]  [30/60]  eta: 0:00:12  lr: 0.000005  loss: 0.4604 (0.5517)  loss_classifier: 0.0627 (0.0802)  loss_box_reg: 0.0737 (0.0991)  loss_mask: 0.3090 (0.3602)  loss_objectness: 0.0061 (0.0058)  loss_rpn_box_reg: 0.0044 (0.0064)  time: 0.4153  data: 0.0178  max mem: 3876
# Epoch: [9]  [40/60]  eta: 0:00:08  lr: 0.000005  loss: 0.4274 (0.5409)  loss_classifier: 0.0698 (0.0789)  loss_box_reg: 0.0682 (0.0981)  loss_mask: 0.2903 (0.3520)  loss_objectness: 0.0060 (0.0055)  loss_rpn_box_reg: 0.0044 (0.0064)  time: 0.4213  data: 0.0183  max mem: 3876
# Epoch: [9]  [50/60]  eta: 0:00:04  lr: 0.000005  loss: 0.4551 (0.5399)  loss_classifier: 0.0701 (0.0792)  loss_box_reg: 0.0682 (0.0978)  loss_mask: 0.3246 (0.3507)  loss_objectness: 0.0059 (0.0057)  loss_rpn_box_reg: 0.0043 (0.0065)  time: 0.4105  data: 0.0198  max mem: 3876
# Epoch: [9]  [59/60]  eta: 0:00:00  lr: 0.000005  loss: 0.4760 (0.5562)  loss_classifier: 0.0827 (0.0826)  loss_box_reg: 0.0840 (0.1042)  loss_mask: 0.3263 (0.3560)  loss_objectness: 0.0059 (0.0059)  loss_rpn_box_reg: 0.0060 (0.0075)  time: 0.4326  data: 0.0208  max mem: 3876
# Epoch: [9] Total time: 0:00:25 (0.4231 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:04  model_time: 0.0840 (0.0840)  evaluator_time: 0.0090 (0.0090)  time: 0.1000  data: 0.0070  max mem: 3876
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0900 (0.0963)  evaluator_time: 0.0110 (0.0135)  time: 0.1241  data: 0.0119  max mem: 3876
# Test: Total time: 0:00:06 (0.1220 s / it)
# Averaged stats: model_time: 0.0900 (0.0963)  evaluator_time: 0.0110 (0.0135)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.754
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.585
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.788
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.326
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.790
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.805
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.708
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.963
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.875
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.367
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.298
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.746
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
# That's it!

# %% [markdown]
# <br>
# <br>
# <br>
